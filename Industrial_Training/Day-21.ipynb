# %% [markdown]
# # Classification Problem Statement

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as ply
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('cleaned_data.csv')

# %%
df
# Out:
#        Gender_Male  Customer Type_disloyal Customer  \
# 0                1                                1
# 1                1                                1
# 2                0                                1
# 3                1                                1
# 4                0                                1
# ...            ...                              ...
# 38900            1                                0
# 38901            1                                0
# 38902            1                                0
# 38903            0                                0
# 38904            1                                0
#
#        Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 0                                   0          0               0
# 1                                   0          1               0
# 2                                   0          1               0
# 3                                   0          1               0
# ...

# %%
y = df[['Customer Type_disloyal Customer']]

# %%
y
# Out:
#        Customer Type_disloyal Customer
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1
# ...                                ...
# 38900                                0
# 38901                                0
# 38902                                0
# 38903                                0
# 38904                                0
#
# [38905 rows x 1 columns]

# %%
x = df

# %%
x
# Out:
#        Gender_Male  Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 0                1                               0          0               0
# 1                1                               0          1               0
# 2                0                               0          1               0
# 3                1                               0          1               0
# 4                0                               0          1               0
# ...            ...                             ...        ...             ...
# 38900            1                               0          0               0
# 38901            1                               0          1               0
# 38902            1                               0          1               0
# 38903            0                               0          0               0
# 38904            1                               0          1               0
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
x_train
# Out:
#        Gender_Male  Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 23318            0                               1          1               0
# 38744            0                               1          1               0
# 35424            1                               0          0               0
# 15726            0                               0          0               0
# 10230            0                               0          0               0
# ...            ...                             ...        ...             ...
# 26971            0                               1          1               0
# 4507             0                               0          1               0
# 2545             1                               0          1               0
# 16278            0                               0          1               0
# 23178            1                               1          1               0
#
# ...

# %%
x_test
# Out:
#        Gender_Male  Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 11566            0                               0          0               0
# 25616            0                               1          1               0
# 34870            0                               1          1               0
# 14484            0                               0          0               0
# 36379            1                               0          0               0
# ...            ...                             ...        ...             ...
# 24387            1                               1          1               0
# 13996            1                               0          1               0
# 35853            0                               0          0               0
# 5005             1                               0          0               0
# 14293            1                               0          1               0
#
# ...

# %%
y_train
# Out:
#        Customer Type_disloyal Customer
# 23318                                0
# 38744                                0
# 35424                                0
# 15726                                1
# 10230                                1
# ...                                ...
# 26971                                0
# 4507                                 1
# 2545                                 1
# 16278                                1
# 23178                                0
#
# [31124 rows x 1 columns]

# %%
y_test
# Out:
#        Customer Type_disloyal Customer
# 11566                                1
# 25616                                0
# 34870                                0
# 14484                                1
# 36379                                0
# ...                                ...
# 24387                                0
# 13996                                1
# 35853                                0
# 5005                                 1
# 14293                                1
#
# [7781 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression  # This algorithm is used for classification problem statement

# %%
lg = LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
round(lg.score(x_train,y_train),2)*100
# Out:
# 86.0

# %%
round(lg.score(x_test, y_test, ),2)*100
# Out:
# 86.0

# %% [markdown]
# OVERFIT PROBLEM -> When the score in training is higher than the score in testing by a considerable amount
#
# High score in training -->  98%
# Low score in testibng --> 75%

# %% [markdown]
# UNDERFIT PROBLEM -> Training sccore is low, but testing score can be either low or high

# %%
pred = lg.predict(x_test)

# %%
y_test['Prediction'] = pred

# %%
y_test
# Out:
#        Customer Type_disloyal Customer  Prediction
# 11566                                1           0
# 25616                                0           0
# 34870                                0           0
# 14484                                1           1
# 36379                                0           0
# ...                                ...         ...
# 24387                                0           0
# 13996                                1           1
# 35853                                0           0
# 5005                                 1           1
# 14293                                1           1
#
# [7781 rows x 2 columns]

# %%
y_test.head(20)
# Out:
#        Customer Type_disloyal Customer  Prediction
# 11566                                1           0
# 25616                                0           0
# 34870                                0           0
# 14484                                1           1
# 36379                                0           0
# 19829                                0           0
# 8907                                 1           1
# 37333                                0           0
# 24284                                0           0
# 27828                                0           0
# 20310                                0           0
# 33076                                0           1
# 15885                                1           1
# 38680                                0           0
# 36654                                0           0
# 26005                                0           0
# 17293                                1           1
# ...

# %%
y_test['Customer Type_disloyal Customer'].value_counts()
# Out:
# Customer Type_disloyal Customer
# 0    4022
# 1    3759
# Name: count, dtype: int64

# %%
y_test['Prediction'].value_counts()
# Out:
# Prediction
# 0    4001
# 1    3780
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix  # helps to analyse the results of our classification model in depth

# %%
confusion_matrix(y_test['Customer Type_disloyal Customer'], y_test['Prediction'])   # It generates a 2-D array (matrix)
# Out:
# array([[3463,  559],
#        [ 538, 3221]], dtype=int64)

# %% [markdown]
# True Positive -> the actual value is 1(True) and the predicted value is also 1 (True)

# %% [markdown]
# False Positive -> the actual value is 0(False) but the predicted value is 1(True)

# %% [markdown]
# False Negative -> the actual value is 1(False) but the predicted value is 0(True)

# %% [markdown]
# True Negative -> the actual value is 0(False) and the predicted value is also 0(False)z

# %% [markdown]
# The True Positive and True Negative values should be high. Their high values signifies the accuracy of the model

# %% [markdown]
# The False Neagative and False Positive values are the error points. Thus their values should be low

# %% [markdown]
# Accuracy = (TP+TN) / (TP+TN+FP+FN)

# %% [markdown]
# Precision = TP/(TP+FP)

# %%
accuracy = (3463+3221)/(3463+3221+559+538)

# %%
accuracy
# Out:
# 0.8590155507004241

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test['Customer Type_disloyal Customer'], y_test['Prediction']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      4022
#            1       0.85      0.86      0.85      3759
#
#     accuracy                           0.86      7781
#    macro avg       0.86      0.86      0.86      7781
# weighted avg       0.86      0.86      0.86      7781

# %%
import joblib

# %%
joblib.dump(lg, 'logistic.lb')
# Out:
# ['logistic.lb']
