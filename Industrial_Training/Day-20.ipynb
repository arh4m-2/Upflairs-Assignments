# %% [markdown]
# # Classification problem statement

# %% [markdown]
# We have to classify

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as ply
import seaborn as sns

# %%
df = pd.read_csv('cust_satisfaction.csv')

# %%
df.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# ...

# %%
df.shape
# Out:
# (103904, 12)

# %%
df.duplicated().sum()
# Out:
# 172

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
df.shape
# Out:
# (103732, 12)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (103422, 12)

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
df.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# ...

# %%
cat_col = df.select_dtypes(include='O')

# %%
cat_col.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied

# %%
num_col = df.select_dtypes(exclude='O')

# %%
num_col.head()
# Out:
#    Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0   13              460                       5                 4
# 1   25              235                       1                 3
# 2   26             1142                       5                 4
# 3   25              562                       2                 3
# 4   61              214                       3                 4
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 0            5                          25                      18.0
# 1            1                           1                       6.0
# 2            5                           0                       0.0
# 3            2                          11                       9.0
# 4            3                           0                       0.0

# %%
cat_col['Class'].value_counts()
# Out:
# Class
# Business    49423
# Eco         46532
# Eco Plus     7467
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# astype()  --> this function is used to change the data type of our columns
cat_col = pd.get_dummies(cat_col, drop_first='if_binary').astype(int)

# %%
cat_col.head()
# Out:
#    Gender_Male  Customer Type_disloyal Customer  \
# 0            1                                0
# 1            1                                1
# 2            0                                0
# 3            0                                0
# 4            1                                0
#
#    Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 0                               1          0               1
# 1                               0          0               0
# 2                               0          0               0
# 3                               0          0               0
# 4                               0          0               0
#
#    satisfaction_satisfied
# 0                       0
# 1                       0
# 2                       1
# 3                       0
# 4                       1

# %%
df['Arrival Delay in Minutes'].astype(int)
# Out:
# 0         18
# 1          6
# 2          0
# 3          9
# 4          0
#           ..
# 103899     0
# 103900     0
# 103901    14
# 103902     0
# 103903     0
# Name: Arrival Delay in Minutes, Length: 103422, dtype: int32

# %%
cat_col
# Out:
#         Gender_Male  Customer Type_disloyal Customer  \
# 0                 1                                0
# 1                 1                                1
# 2                 0                                0
# 3                 0                                0
# 4                 1                                0
# ...             ...                              ...
# 103899            0                                1
# 103900            1                                0
# 103901            1                                1
# 103902            0                                1
# 103903            1                                0
#
#         Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 0                                    1          0               1
# 1                                    0          0               0
# 2                                    0          0               0
# ...

# %%
num_col
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0        13              460                       5                 4
# 1        25              235                       1                 3
# 2        26             1142                       5                 4
# 3        25              562                       2                 3
# 4        61              214                       3                 4
# ...     ...              ...                     ...               ...
# 103899   23              192                       2                 4
# 103900   49             2347                       5                 5
# 103901   30             1995                       4                 4
# 103902   22             1000                       1                 1
# 103903   27             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# ...

# %%
df2 = pd.concat([cat_col, num_col], axis=1)

# %%
df2.head()
# Out:
#    Gender_Male  Customer Type_disloyal Customer  \
# 0            1                                0
# 1            1                                1
# 2            0                                0
# 3            0                                0
# 4            1                                0
#
#    Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 0                               1          0               1
# 1                               0          0               0
# 2                               0          0               0
# 3                               0          0               0
# 4                               0          0               0
#
#    satisfaction_satisfied  Age  Flight Distance  Inflight entertainment  \
# 0                       0   13              460                       5
# 1                       0   25              235                       1
# 2                       1   26             1142                       5
# ...

# %%
df2.isnull().sum()
# Out:
# Gender_Male                        0
# Customer Type_disloyal Customer    0
# Type of Travel_Personal Travel     0
# Class_Eco                          0
# Class_Eco Plus                     0
# satisfaction_satisfied             0
# Age                                0
# Flight Distance                    0
# Inflight entertainment             0
# Baggage handling                   0
# Cleanliness                        0
# Departure Delay in Minutes         0
# Arrival Delay in Minutes           0
# dtype: int64

# %%
# For classification problem statement, the data points for both the categories should be similar. There should not be much difference. 
#If the have a cast difference, this is called as 'Unbalanced Data'

# %%
df2['Customer Type_disloyal Customer'].value_counts()   # This data is Unbalanced
# Out:
# Customer Type_disloyal Customer
# 0    84517
# 1    18905
# Name: count, dtype: int64

# %%
disloyal_cust = df2[df2['Customer Type_disloyal Customer'] == 0 ]
loyal_cust = df2[df2['Customer Type_disloyal Customer'] == 1 ]

# %%
disloyal_cust
# Out:
#         Gender_Male  Customer Type_disloyal Customer  \
# 0                 1                                0
# 2                 0                                0
# 3                 0                                0
# 4                 1                                0
# 5                 0                                0
# ...             ...                              ...
# 103896            1                                0
# 103897            0                                0
# 103898            1                                0
# 103900            1                                0
# 103903            1                                0
#
#         Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 0                                    1          0               1
# 2                                    0          0               0
# 3                                    0          0               0
# ...

# %%
loyal_cust.shape  , disloyal_cust.shape
# Out:
# ((18905, 13), (84517, 13))

# %%
disloyal_cust = disloyal_cust.sample(20000)  # returns 20000 rows from our data frame randomly

# %%
disloyal_cust.shape
# Out:
# (20000, 13)

# %%
final_df = pd.concat([loyal_cust, disloyal_cust])

# %%
final_df  # This data is balanced
# Out:
#        Gender_Male  Customer Type_disloyal Customer  \
# 1                1                                1
# 9                1                                1
# 10               0                                1
# 15               1                                1
# 24               0                                1
# ...            ...                              ...
# 96503            1                                0
# 71927            1                                0
# 38862            1                                0
# 64937            0                                0
# 25044            1                                0
#
#        Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 1                                   0          0               0
# 9                                   0          1               0
# 10                                  0          1               0
# 15                                  0          1               0
# ...

# %%
final_df.isnull().sum()
# Out:
# Gender_Male                        0
# Customer Type_disloyal Customer    0
# Type of Travel_Personal Travel     0
# Class_Eco                          0
# Class_Eco Plus                     0
# satisfaction_satisfied             0
# Age                                0
# Flight Distance                    0
# Inflight entertainment             0
# Baggage handling                   0
# Cleanliness                        0
# Departure Delay in Minutes         0
# Arrival Delay in Minutes           0
# dtype: int64

# %%
final_df.to_csv('cleaned_data.csv', index=False)
