# %% [markdown]
# ## SEABORN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings  # ignores all warnings in the code
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('tips')  # importing dataset from the seaborn library as it has bulit in sample datasets

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# All function of the matplotlib library as present in seaborn

# %%
## relplot() -> relational plot
## catplot() -> catagorical plot

# %% [markdown]
# #relplot()

# %%
sns.relplot(data=df, x='total_bill', y='tip')  # makes a scatter plot

# %%
sns.relplot(data=df, x='total_bill', y='tip', hue='sex')

# %%
sns.relplot(data=df, x='total_bill', y='tip', hue='sex', style='day')

# %%
sns.relplot(data=df, x='total_bill', y='tip', hue='sex', style='day', col='day')

# %% [markdown]
# With relplot we can make 2 types of plots -> scatter plot and line plot (scatter by default)

# %%
sns.relplot(data=df, x='total_bill', y='tip', hue='sex', style='day', col='day', kind='line')

# %% [markdown]
# #catplot() -> use catplot when one axis has catogorical value and other have numerical value

# %%
sns.catplot(x='smoker', y='total_bill', data=df)

# %%
sns.catplot(x='smoker', y='total_bill', data=df, kind='bar')

# %%
sns.catplot(data=df, x='day', y='total_bill')

# %%
sns.catplot(data=df, x='day', y='total_bill', hue='sex')

# %%
sns.catplot(data=df, x='day', y='total_bill', hue='sex', kind='bar')

# %%
sns.catplot(data=df, x='day', y='total_bill', hue='sex', kind='swarm')

# %%
sns.catplot(data=df, x='day', y='total_bill', hue='sex', kind='boxen')

# %%
sns.catplot(data=df, x='day', y='total_bill', hue='sex', kind='violin')

# %%
# making scatterplot directly
sns.scatterplot(x='total_bill', y='tip', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x='day', y='total_bill', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', data=df, hue='sex')
plt.title('Cafe Data')  # matplotlib func to set the title of data
plt.xlabel('DAYS')  # func to change label of X-axis
plt.ylabel('TOTAL BILL') # func to change label of y-axis
plt.show()  ## this show() func is from matplotlib

# %% [markdown]
# ## PIE CHART

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
labels = list(df['day'].value_counts().keys())
labels
# Out:
# ['Sat', 'Sun', 'Thur', 'Fri']

# %%
values = list(df['day'].value_counts().values)
values
# Out:
# [87, 76, 62, 19]

# %%
plt.pie(values, labels=labels)
plt.show()

# %%
# ec -> edgecolor , k-> black
plt.pie(values, labels=labels, wedgeprops={'ec' : 'k'} )  # wedgeprop takes a dictionary
plt.show()

# %%
lst = [0,0,0,0.4]  # we can change the walue of 0 to increase spacing of a slice. ( take value between 0-1)
plt.pie(values, labels=labels, wedgeprops={'ec' : 'k'}, explode=lst )
plt.show()

# %%
lst = [0,0,0,0.4] 
sns.set(rc={'figure.figsize': (4,4)}) # to change the size of the chart
plt.pie(values, labels=labels, wedgeprops={'ec' : 'k'}, explode=lst, autopct='%1.2f%%', shadow=True)  # .2 means upto 2 decimal places
plt.title('Cafe Data - Daywise')
# plt.savefig("PieChart")  # to save the pie chart
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='smoker', y='total_bill', data=df, kind='bar', hue='day', row='sex')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill', y='size', data=df, kind='line')

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(df['total_bill'])  # always use numerival valued columns for box plot
sns.set(rc={'figure.figsize': (10,10)})
